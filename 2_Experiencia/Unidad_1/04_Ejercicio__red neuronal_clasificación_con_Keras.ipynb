# %% [markdown]
# # Ejercicio práctico: implementar una red neuronal para clasificación utilizando Keras

# %%
import keras
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
# Generar un conjunto de datos de clasificación sintético
X, y = make_classification(n_samples=100, n_features=5, n_classes=2)

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Convertir las etiquetas a codificación one-hot
y_train_categorical = keras.utils.to_categorical(y_train)
y_test_categorical = keras.utils.to_categorical(y_test)

# %%
# Crear una instancia de un modelo secuencial de keras
model = keras.models.Sequential()

# %%
# Añadir una capa oculta con 10 neuronas y activación ReLu
model.add(keras.layers.Dense(10, activation='relu', input_shape=(X_train.shape[1],)))

# Añadir una capa de salida con 2 neuronas (una para cada clase) y activación softmax
model.add(keras.layers.Dense(2, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilar el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Entrenar el modelo
model.fit(X_train, y_train_categorical, epochs=10, batch_size=32, validation_data=(X_test, y_test_categorical))
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.5188 - loss: 0.9959 - val_accuracy: 0.6500 - val_loss: 0.7978
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5758 - loss: 0.9506 - val_accuracy: 0.7500 - val_loss: 0.7755
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5523 - loss: 0.9027 - val_accuracy: 0.7500 - val_loss: 0.7541
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5195 - loss: 0.9075 - val_accuracy: 0.7500 - val_loss: 0.7338
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6086 - loss: 0.8062 - val_accuracy: 0.7500 - val_loss: 0.7142
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6406 - loss: 0.8176 - val_accuracy: 0.7500 - val_loss: 0.6956
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6195 - loss: 0.8290 - val_accuracy: 0.6500 - val_loss: 0.6776
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6875 - loss: 0.7859 - val_accuracy: 0.6500 - val_loss: 0.6605
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6625 - loss: 0.8042 - val_accuracy: 0.6500 - val_loss: 0.6447
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7016 - loss: 0.7284 - val_accuracy: 0.6500 - val_loss: 0.6293

# %%
# Evaluar el modelo en el conjunto de prueba
loss, accuracy = model.evaluate(X_test, y_test_categorical)
print('Pérdida en el conjunto de prueba:', loss)
print('Precisión en el conjunto de prueba:', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6500 - loss: 0.6293
# Pérdida en el conjunto de prueba: 0.6293147206306458
# Precisión en el conjunto de prueba: 0.6499999761581421
